# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhaumik181/Challenge-ques/blob/main/Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
L = ["Ram","shyam","Aman",5,2,3,7]
L=[str(i) for i in L]
print(L)
L.sort()
print(L)
# Out:
# ['Ram', 'shyam', 'Aman', '5', '2', '3', '7']
# ['2', '3', '5', '7', 'Aman', 'Ram', 'shyam']

# %%
L = ["Ram","1","shyam","2","Aman","3"]
print(L)
L.sort()
print(L)
# Out:
# ['Ram', '1', 'shyam', '2', 'Aman', '3']
# ['1', '2', '3', 'Aman', 'Ram', 'shyam']

# %%
L = ["Ram","shyam","Aman",5,2,3,7]
L=[str(i) for i in L]
L.sort()
print(L)

L1 = []
for i in L:
  try:
    L1.append(int(i))
  except:
      L1.append(i)
      print(L1)
# Out:
# ['2', '3', '5', '7', 'Aman', 'Ram', 'shyam']
# [2, 3, 5, 7, 'Aman']
# [2, 3, 5, 7, 'Aman', 'Ram']
# [2, 3, 5, 7, 'Aman', 'Ram', 'shyam']

# %%
import time
t1 = time.time()

for i in  range(100000):
  for j in range(100000):
    x=900
    t2 = time.time()

    print("Total Time",t2-t1)
# Out:
# Streaming output truncated to the last 5000 lines.
# Total Time 136.2350034713745
# Total Time 136.23502945899963
# Total Time 136.23509764671326
# Total Time 136.235125541687
# Total Time 136.23515224456787
# Total Time 136.23517990112305
# Total Time 136.23520827293396
# Total Time 136.23523545265198
# Total Time 136.23526239395142
# Total Time 136.23528957366943
# Total Time 136.23531651496887
# Total Time 136.23535132408142
# Total Time 136.23538637161255
# Total Time 136.23541402816772
# Total Time 136.23544025421143
# Total Time 136.23547077178955
# Total Time 136.23549675941467
# Total Time 136.2355237007141
# Total Time 136.2355501651764
# Total Time 136.23557662963867
# Total Time 136.23560404777527
# Total Time 136.23563051223755
# Total Time 136.2356562614441
# Total Time 136.2356822490692
# Total Time 136.2357096672058
# Total Time 136.23573660850525
# Total Time 136.2357635498047
# Total Time 136.23579025268555
# Total Time 136.2358157634735
# ...
